# %%
text = '''Электрика материалы черновые 52.645
Электрика работы 37.450
Сантехника работы 47.750
Сантехника материалы 22.086
Унитаз с инсталляцией 28.600
Отделочные материалы черновые 77.315 + 24.750 + 3.054
Штукатуры работы 99.761 + 1.118
Шпаклёвка и ГКЛ работы 84.800
Плитка 110.750
Плитка работа 41.170 + 109.530 + 29.520
Дверь 30.000
Дверь установка 4.500
Вывоз мусора 15.500
Гипсокартон 8.425
Ванна 26.600
6.980 + 506 + 799 + 2.578 (вентиляция и сифон) + 200 + 726 + 240 + 3.720 + 485
Лючки 3.665
Обои 27.889 + 1.294
Обои + краска работа 66.099
Краска 5.200
Ламинат 53.810
Ламинат работа 23.988
Плинтус 22.000
Полотенцесушитель 6.800
Душевая стойка 16.800
Двери межкомнатные 23.950
Смеситель 8.521
Раковина 7.535 + 1200 затычка
Бойлер 6.057
Двери установка 8.000
Потолок 65.000
Розетки и выключатели 22.465
Светильники на балкон 3.120
Светильник в гостиную 1900
Молдинг 995
Освещение 4.485
Профиль (порожки) 1.584
Лента + направляющие 6.352
Установка сантехники 16.470
Плинтус работа 11.900
Установка электрики 20.000'''
total = 0
text = text.split()
for word in text:
    if word.isdigit():
        total += int(word)
    if '.' in word:
        word = (float(word))*1000
        total += word
print(total)
# Out:
# 1308637.0
